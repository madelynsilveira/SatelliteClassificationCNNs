# %% [markdown]
# #Satellite Image Classification with Convolutional Neural Networks
#
# by Madelyn Silveira, Zivanai Mutaya, James Chillery
#
# April 2025

# %% [markdown]
# For this project, we will use the Functional Map of the World dataset, created by the Intelligence Advanced Research Projects Activity (IARPA). We download it from their github: https://github.com/fMoW/dataset.
#
# @inproceedings{fmow2018,
#   title={Functional Map of the World},
#   author={Christie, Gordon and Fendley, Neil and Wilson, James and Mukherjee, Ryan},
#   booktitle={CVPR},
#   year={2018}
# }

# %% [markdown]
# The full dataset contains terabytes of multi-channel data. We will use a simplified version with only rgb channels. Since this simplified version is still around 200GB -- exceeding the storage of collab -- we will stream the data from AWS S3, filtering for relevant classes as we go. We chose target classes that we thought might be useful to characterize energy consumption since 2002.

# %% [markdown]
# **Define Target Classes**
#
# The focus of this project is to analyze energy production and distribution, so we will focus on classes pertaining to that domain. Reducing the classes also significantly reduces computational load.

# %%
# this names all classes in the dataset
all_classes = [
    "airport", "airport_hangar", "airport_terminal", "amusement_park",
    "aquaculture", "archaeological_site", "barn", "border_checkpoint",
    "burial_site", "car_dealership", "construction_site", "crop_field",
    "dam", "debris_or_rubble", "educational_institution", "electric_substation",
    "factory_or_powerplant", "fire_station", "flooded_road", "fountain",
    "gas_station", "golf_course", "ground_transportation_station", "helipad",
    "hospital", "impoverished_settlement", "interchange", "lake_or_pond",
    "lighthouse", "military_facility", "multi-unit_residential",
    "nuclear_powerplant", "office_building", "oil_or_gas_facility", "park",
    "parking_lot_or_garage", "place_of_worship", "police_station", "port",
    "prison", "race_track", "railway_bridge", "recreational_facility",
    "road_bridge", "runway", "shipyard", "shopping_mall",
    "single-unit_residential", "smokestack", "solar_farm", "space_facility",
    "stadium", "storage_tank", "surface_mine", "swimming_pool", "toll_booth",
    "tower", "tunnel_opening", "waste_disposal", "water_treatment_facility",
    "wind_farm", "zoo"]

# these are the classes we want to explore for this project
target_classes = [
    "electric_substation", "factory_or_powerplant", "gas_station",
    "nuclear_powerplant", "oil_or_gas_facility", "solar_farm", "space_facility",
    "waste_disposal", "water_treatment_facility", "wind_farm"]

# examples are labeled with the numerical value for each class
target_ids = []
print("Target Classes:\n")
for target_class in target_classes:
    try:
        idx = all_classes.index(target_class)
        target_ids.append(idx)
        print(f"{idx}: {target_class}")
    except ValueError:
        print(f"{target_class} not found in all_classes")

print(f"\nLength: {len(target_ids)}")

# view numbers for all classes
# for idx, c in enumerate(all_classes):
#     print(f"{idx}: {c}")
# Out:
# Target Classes:
#
# 15: electric_substation
# 16: factory_or_powerplant
# 20: gas_station
# 31: nuclear_powerplant
# 33: oil_or_gas_facility
# 49: solar_farm
# 50: space_facility
# 58: waste_disposal
# 59: water_treatment_facility
# 60: wind_farm
#
# Length: 10

# %%
# !pip3 install boto3
# Out:
# Requirement already satisfied: boto3 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (1.38.3)
# Requirement already satisfied: botocore<1.39.0,>=1.38.3 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from boto3) (1.38.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from boto3) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from botocore<1.39.0,>=1.38.3->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from botocore<1.39.0,>=1.38.3->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in /Users/maddysilveira/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.3->boto3) (1.17.0)

# %%
import boto3
import bz2
import json
import pprint

from botocore import UNSIGNED
from botocore.config import Config

# using Amazon Single Storage Service with a guest account
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))
bucket_name = 'spacenet-dataset'
prefix = 'Hosted-Datasets/fmow/fmow-rgb/'

# view the README.md from the S3 bucket
s3.download_file(bucket_name, prefix + 'README.md', 'README.md')
with open('README.md', 'r') as f:
    print(f.read())
# Out:
# # Functional Map of the World (fMoW) RGB Dataset
# The data in this bucket represents the JPEG-compressed RGB version of the dataset that was created for the fMoW Challenge. There is another bucket located at s3://spacenet-dataset/fmow/fmow-full that contains the same imagery as this bucket except that all imagery is in a less-compressed TIFF format and multispectral imagery contains 4 or 8 channels of information. The fMoW-full dataset is significantly larger in size, but recommended for those of you who would like less compressed imagery and/or intend to utilize multispectral information.
#
# ## The Problem
# Intelligence analysts, policy makers, and first responders around the world rely on geospatial land use data to inform crucial decisions about global defense and humanitarian activities. Historically, analysts have manually identified and classified geospatial information by comparing and analyzing satellite images, but that process is time consuming and insufficient to support disaster response.
#
# The fMoW Challenge seeks to foster breakthroughs in the automated analysis of overhead imagery by harnessing the collective power of the global data science and machine learning communities. Can you build algorithms to classify facility, building, and land use from satellite imagery?  We are inviting solvers from around the world to develop deep learning and other automated techniques to classify points of interest from satellite imagery.
#
# ## Connect with Us
# Website: [https://www.iarpa.gov/challenges/fmow.html](https://www.iarpa.gov/challenges/fmow.html)
# GitHub: [https://github.com/fMoW](https://github.com/fMoW)
# Twitter: [@IARPAnews](https://twitter.com/IARPAnews) and [#IAPRAfMoW](https://instagram.com/tags/IARPAfMoW)
# Email: [functionalmap@iarpa.gov](mailto:functionalmap@iarpa.gov)
#
# ## About IARPA
# The Intelligence Advanced Research Projects Activity (IARPA), within the Office of the Director of National Intelligence (ODNI), focuses on high-risk, high-payoff research programs to tackle difficult challenges of the agencies and disciplines in the Intelligence Community. IARPA Challenges invite experts from the broader research community of academia and industry, and developers to participate in IARPA research in a convenient, efficient, and non-contractual way.
#
# ## Data Details
# For more information about the files and folders included here, please see our [GitHub dataset page](https://github.com/fmow/dataset).

# %%
# download and load the filed directory
s3.download_file(bucket_name, prefix + 'manifest.json.bz2', 'manifest.json.bz2')
with bz2.open('manifest.json.bz2', 'rt') as f:
    manifest = json.load(f)

# view the beginning structure
pprint.pprint(manifest[:20])
# Out:
# ['CHANGELOG.md',
#  'IARPA-fMoW.pdf',
#  'LICENSE',
#  'README.md',
#  'fMoW-rgb_seqandgt_v1.2.1.torrent',
#  'fMoW-rgb_test_v1.0.0.torrent',
#  'fMoW-rgb_trainval_v1.0.0.torrent',
#  'fMoW-rgb_val_sample_v1.1.0.torrent',
#  'groundtruth.tar.bz2',
#  'manifest.json.bz2',
#  'seq/0000000/0000000_0_msrgb.jpg',
#  'seq/0000000/0000000_0_msrgb.json',
#  'seq/0000000/0000000_0_rgb.jpg',
#  'seq/0000000/0000000_0_rgb.json',
#  'seq/0000000/0000000_2_msrgb.jpg',
#  'seq/0000000/0000000_2_msrgb.json',
#  'seq/0000000/0000000_2_rgb.jpg',
#  'seq/0000000/0000000_2_rgb.json',
#  'seq/0000000/0000000_4_msrgb.jpg',
#  'seq/0000000/0000000_4_msrgb.json']

# %%
from collections import defaultdict

# let's check the folder structure of the manifest
folder_counts = defaultdict(int)
for path in manifest:
    if '/' in path:
        folder = path.split('/')[0]
        folder_counts[folder] += 1
    else:
        folder_counts['[root]'] += 1

for folder, count in folder_counts.items():
    print(f"{folder}/ : {count} items")
# Out:
# [root]/ : 11 items
# seq/ : 215040 items
# test/ : 213892 items
# train/ : 1454288 items
# val/ : 212162 items

# %% [markdown]
# The seq folder contains temporal sequences of photos. It is useful for analyzing things like flooded roads. We will not be using it for our project.

# %%
# how are those folders structured?
subfolder_counts = defaultdict(int)
for path in manifest:
    parts = path.split('/')
    if len(parts) > 1:
        subfolder = '/'.join(parts[:2])
        subfolder_counts[subfolder] += 1
for subfolder, count in subfolder_counts.items():
    print(f"{subfolder}/ : {count} items")
# Out:
# seq/0000000/ : 12 items
# seq/0000001/ : 52 items
# seq/0000002/ : 4 items
# seq/0000003/ : 4 items
# seq/0000004/ : 4 items
# seq/0000005/ : 12 items
# seq/0000006/ : 4 items
# seq/0000007/ : 12 items
# seq/0000008/ : 28 items
# seq/0000009/ : 32 items
# seq/0000010/ : 8 items
# seq/0000011/ : 8 items
# seq/0000012/ : 4 items
# seq/0000013/ : 8 items
# seq/0000014/ : 4 items
# seq/0000015/ : 8 items
# seq/0000016/ : 4 items
# seq/0000017/ : 40 items
# seq/0000018/ : 20 items
# seq/0000019/ : 4 items
# seq/0000020/ : 56 items
# seq/0000021/ : 8 items
# seq/0000022/ : 8 items
# seq/0000023/ : 16 items
# seq/0000024/ : 20 items
# seq/0000025/ : 4 items
# seq/0000026/ : 12 items
# seq/0000027/ : 16 items
# seq/0000028/ : 40 items
# seq/0000029/ : 40 items
# seq/0000030/ : 36 items
# seq/0000031/ : 8 items
# seq/0000032/ : 8 items
# seq/0000033/ : 8 items
# seq/0000034/ : 4 items
# seq/0000035/ : 4 items
# seq/0000036/ : 36 items
# seq/0000037/ : 36 items
# seq/0000038/ : 12 items
# seq/0000039/ : 4 items
# seq/0000040/ : 8 items
# seq/0000041/ : 12 items
# seq/0000042/ : 64 items
# seq/0000043/ : 20 items
# seq/0000044/ : 16 items
# seq/0000045/ : 4 items
# seq/0000046/ : 16 items
# seq/0001984/ : 8 items
# seq/0001985/ : 4 items
# seq/0001986/ : 40 items
# seq/0001987/ : 16 items
# seq/0001988/ : 40 items
# seq/0001989/ : 16 items
# seq/0001990/ : 16 items
# seq/0001991/ : 8 items
# seq/0001992/ : 4 items
# seq/0001993/ : 12 items
# seq/0001994/ : 16 items
# seq/0001995/ : 20 items
# seq/0001996/ : 12 items
# seq/0001997/ : 56 items
# seq/0001998/ : 4 items
# seq/0001999/ : 4 items
# seq/0002000/ : 12 items
# seq/0002001/ : 32 items
# seq/0002002/ : 12 items
# seq/0002003/ : 8 items
# seq/0002004/ : 16 items
# seq/0002005/ : 16 items
# seq/0002006/ : 4 items
# seq/0002007/ : 24 items
# seq/0002008/ : 4 items
# seq/0002009/ : 24 items
# seq/0002010/ : 8 items
# seq/0002011/ : 8 items
# seq/0002012/ : 28 items
# seq/0002013/ : 16 items
# seq/0002014/ : 4 items
# seq/0002015/ : 12 items
# seq/0002016/ : 40 items
# seq/0002017/ : 4 items
# seq/0002018/ : 20 items
# seq/0002019/ : 8 items
# seq/0002020/ : 8 items
# seq/0002021/ : 32 items
# seq/0002022/ : 24 items
# seq/0002023/ : 24 items
# seq/0002024/ : 32 items
# seq/0002025/ : 44 items
# seq/0002026/ : 20 items
# seq/0002027/ : 12 items
# seq/0002028/ : 64 items
# seq/0002029/ : 24 items
# seq/0002030/ : 16 items
# ...
# test/0011524/ : 16 items
# test/0011525/ : 12 items
# test/0011526/ : 12 items
# test/0011527/ : 16 items
# test/0011528/ : 20 items
# test/0011529/ : 36 items
# test/0011530/ : 8 items
# test/0011531/ : 8 items
# test/0011532/ : 20 items
# test/0011533/ : 28 items
# test/0011534/ : 12 items
# test/0011535/ : 12 items
# test/0011536/ : 12 items
# test/0011537/ : 8 items
# test/0011538/ : 8 items
# test/0011539/ : 24 items
# test/0011540/ : 48 items
# test/0011541/ : 16 items
# test/0011542/ : 32 items
# test/0011543/ : 12 items
# test/0011544/ : 4 items
# test/0011545/ : 28 items
# test/0011546/ : 28 items
# test/0011547/ : 12 items
# test/0011548/ : 8 items
# test/0011549/ : 16 items
# test/0011550/ : 12 items
# test/0011551/ : 8 items
# test/0011552/ : 24 items
# test/0011553/ : 4 items
# test/0011554/ : 52 items
# test/0011555/ : 32 items
# test/0011556/ : 8 items
# test/0011557/ : 28 items
# test/0011558/ : 32 items
# test/0011559/ : 8 items
# test/0011560/ : 20 items
# test/0011561/ : 16 items
# test/0011562/ : 4 items
# test/0011563/ : 36 items
# test/0011564/ : 8 items
# test/0011565/ : 16 items
# test/0011566/ : 56 items
# test/0011567/ : 4 items
# test/0011568/ : 16 items
# test/0011569/ : 32 items
# test/0011570/ : 32 items
# test/0011571/ : 4 items
# test/0011572/ : 40 items
# test/0011573/ : 12 items
# test/0011574/ : 28 items
# test/0011575/ : 12 items
# test/0011576/ : 12 items
# test/0011577/ : 12 items
# test/0011578/ : 4 items
# test/0011579/ : 20 items
# test/0011580/ : 8 items
# test/0011581/ : 16 items
# test/0011582/ : 16 items
# test/0011583/ : 36 items
# test/0011584/ : 20 items
# test/0011585/ : 24 items
# test/0011586/ : 24 items
# test/0011587/ : 24 items
# test/0011588/ : 8 items
# test/0011589/ : 28 items
# test/0011590/ : 28 items
# test/0011591/ : 20 items
# test/0011592/ : 28 items
# test/0011593/ : 24 items
# test/0011594/ : 76 items
# test/0011595/ : 44 items
# test/0011596/ : 8 items
# test/0011597/ : 8 items
# test/0011598/ : 40 items
# test/0011599/ : 20 items
# test/0011600/ : 8 items
# test/0011601/ : 8 items
# test/0011602/ : 4 items
# test/0011603/ : 28 items
# test/0011604/ : 28 items
# test/0011605/ : 4 items
# test/0011606/ : 4 items
# test/0011607/ : 12 items
# test/0011608/ : 24 items
# test/0011609/ : 8 items
# test/0011610/ : 8 items
# test/0011611/ : 40 items
# test/0011612/ : 8 items
# test/0011613/ : 8 items
# test/0011614/ : 4 items
# test/0011615/ : 4 items
# test/0011616/ : 60 items
# test/0011617/ : 16 items
# test/0011618/ : 32 items
# test/0011619/ : 28 items
# test/0011620/ : 16 items
# test/0011621/ : 4 items
# test/0011622/ : 8 items
# test/0011623/ : 16 items
# test/0011624/ : 36 items
# test/0011625/ : 4 items
# test/0011626/ : 20 items
# test/0011627/ : 32 items
# test/0011628/ : 8 items
# test/0011629/ : 12 items
# test/0011630/ : 32 items
# test/0011631/ : 28 items
# test/0011632/ : 12 items
# test/0011633/ : 24 items
# test/0011634/ : 32 items
# test/0011635/ : 4 items
# test/0011636/ : 4 items
# test/0011637/ : 44 items
# test/0011638/ : 36 items
# test/0011639/ : 76 items
# test/0011640/ : 16 items
# test/0011641/ : 12 items
# test/0011642/ : 8 items
# test/0011643/ : 4 items
# test/0011644/ : 36 items
# test/0011645/ : 8 items
# test/0011646/ : 8 items
# test/0011647/ : 12 items
# test/0011648/ : 36 items
# test/0011649/ : 4 items
# test/0011650/ : 16 items
# test/0011651/ : 16 items
# test/0011652/ : 8 items
# test/0011653/ : 32 items
# test/0011654/ : 36 items
# test/0011655/ : 44 items
# test/0011656/ : 8 items
# test/0011657/ : 16 items
# test/0011658/ : 24 items
# test/0011659/ : 36 items
# test/0011660/ : 24 items
# test/0011661/ : 20 items
# test/0011662/ : 40 items
# test/0011663/ : 4 items
# test/0011664/ : 64 items
# test/0011665/ : 8 items
# test/0011666/ : 32 items
# test/0011667/ : 8 items
# test/0011668/ : 4 items
# test/0011669/ : 12 items
# test/0011670/ : 4 items
# test/0011671/ : 16 items
# test/0011672/ : 24 items
# test/0011673/ : 4 items
# test/0011674/ : 4 items
# test/0011675/ : 12 items
# test/0011676/ : 36 items
# test/0011677/ : 16 items
# test/0011678/ : 20 items
# test/0011679/ : 16 items
# test/0011680/ : 4 items
# test/0011681/ : 40 items
# test/0011682/ : 24 items
# test/0011683/ : 40 items
# test/0011684/ : 40 items
# test/0011685/ : 80 items
# test/0011686/ : 24 items
# test/0011687/ : 12 items
# test/0011688/ : 32 items
# test/0011689/ : 12 items
# test/0011690/ : 16 items
# test/0011691/ : 60 items
# test/0011692/ : 12 items
# test/0011693/ : 4 items
# test/0011694/ : 40 items
# test/0011695/ : 20 items
# test/0011696/ : 16 items
# test/0011697/ : 12 items
# test/0011698/ : 12 items
# test/0011699/ : 28 items
# test/0011700/ : 8 items
# test/0011701/ : 16 items
# test/0011702/ : 36 items
# test/0011703/ : 40 items
# test/0011704/ : 20 items
# test/0011705/ : 32 items
# test/0011706/ : 60 items
# test/0011707/ : 16 items
# test/0011708/ : 36 items
# test/0011709/ : 20 items
# test/0011710/ : 8 items
# test/0011711/ : 12 items
# test/0011712/ : 4 items
# test/0011713/ : 32 items
# test/0011714/ : 40 items
# test/0011715/ : 28 items
# test/0011716/ : 32 items
# test/0011717/ : 16 items
# test/0011718/ : 12 items
# test/0011719/ : 4 items
# test/0011720/ : 40 items
# test/0011721/ : 28 items
# test/0011722/ : 12 items
# test/0011723/ : 36 items
# test/0011724/ : 20 items
# test/0011725/ : 28 items
# test/0011726/ : 4 items
# test/0011727/ : 8 items
# test/0011728/ : 16 items
# test/0011729/ : 4 items
# test/0011730/ : 4 items
# test/0011731/ : 32 items
# test/0011732/ : 12 items
# test/0011733/ : 28 items
# test/0011734/ : 20 items
# test/0011735/ : 36 items
# test/0011736/ : 8 items
# test/0011737/ : 20 items
# test/0011738/ : 16 items
# test/0011739/ : 8 items
# test/0011740/ : 8 items
# test/0011741/ : 8 items
# test/0011742/ : 16 items
# test/0011743/ : 24 items
# test/0011744/ : 4 items
# test/0011745/ : 32 items
# test/0011746/ : 8 items
# test/0011747/ : 40 items
# test/0011748/ : 12 items
# test/0011749/ : 12 items
# test/0011750/ : 16 items
# test/0011751/ : 16 items
# test/0011752/ : 32 items
# test/0011753/ : 12 items
# test/0011754/ : 16 items
# test/0011755/ : 4 items
# test/0011756/ : 16 items
# test/0011757/ : 8 items
# test/0011758/ : 36 items
# test/0011759/ : 8 items
# test/0011760/ : 12 items
# test/0011761/ : 4 items
# test/0011762/ : 24 items
# test/0011763/ : 12 items
# test/0011764/ : 12 items
# test/0011765/ : 16 items
# test/0011766/ : 28 items
# test/0011767/ : 12 items
# test/0011768/ : 32 items
# test/0011769/ : 20 items
# test/0011770/ : 8 items
# test/0011771/ : 40 items
# test/0011772/ : 28 items
# test/0011773/ : 12 items
# test/0011774/ : 52 items
# test/0011775/ : 36 items
# test/0011776/ : 4 items
# test/0011777/ : 16 items
# test/0011778/ : 76 items
# test/0011779/ : 4 items
# test/0011780/ : 28 items
# test/0011781/ : 40 items
# test/0011782/ : 4 items
# test/0011783/ : 32 items
# test/0011784/ : 8 items
# test/0011785/ : 64 items
# test/0011786/ : 24 items
# test/0011787/ : 16 items
# test/0011788/ : 48 items
# test/0011789/ : 40 items
# test/0011790/ : 36 items
# test/0011791/ : 4 items
# test/0011792/ : 12 items
# test/0011793/ : 20 items
# test/0011794/ : 16 items
# test/0011795/ : 16 items
# test/0011796/ : 16 items
# test/0011797/ : 8 items
# test/0011798/ : 28 items
# test/0011799/ : 8 items
# test/0011800/ : 32 items
# test/0011801/ : 20 items
# test/0011802/ : 12 items
# test/0011803/ : 20 items
# test/0011804/ : 12 items
# test/0011805/ : 32 items
# test/0011806/ : 8 items
# test/0011807/ : 32 items
# test/0011808/ : 8 items
# test/0011809/ : 8 items
# test/0011810/ : 4 items
# test/0011811/ : 20 items
# test/0011812/ : 4 items
# test/0011813/ : 24 items
# test/0011814/ : 12 items
# test/0011815/ : 20 items
# test/0011816/ : 12 items
# test/0011817/ : 40 items
# test/0011818/ : 72 items
# test/0011819/ : 36 items
# test/0011820/ : 24 items
# test/0011821/ : 24 items
# test/0011822/ : 4 items
# test/0011823/ : 24 items
# test/0011824/ : 4 items
# test/0011825/ : 24 items
# test/0011826/ : 12 items
# test/0011827/ : 4 items
# test/0011828/ : 12 items
# test/0011829/ : 16 items
# test/0011830/ : 28 items
# test/0011831/ : 12 items
# test/0011832/ : 4 items
# test/0011833/ : 16 items
# test/0011834/ : 4 items
# test/0011835/ : 28 items
# test/0011836/ : 40 items
# test/0011837/ : 4 items
# test/0011838/ : 28 items
# test/0011839/ : 4 items
# test/0011840/ : 8 items
# test/0011841/ : 4 items
# test/0011842/ : 4 items
# test/0011843/ : 32 items
# test/0011844/ : 12 items
# test/0011845/ : 32 items
# test/0011846/ : 32 items
# test/0011847/ : 4 items
# test/0011848/ : 24 items
# test/0011849/ : 12 items
# test/0011850/ : 4 items
# test/0011851/ : 72 items
# test/0011852/ : 4 items
# test/0011853/ : 12 items
# test/0011854/ : 12 items
# test/0011855/ : 4 items
# test/0011856/ : 4 items
# test/0011857/ : 24 items
# test/0011858/ : 16 items
# test/0011859/ : 4 items
# test/0011860/ : 40 items
# test/0011861/ : 28 items
# test/0011862/ : 4 items
# test/0011863/ : 4 items
# test/0011864/ : 40 items
# test/0011865/ : 4 items
# test/0011866/ : 36 items
# test/0011867/ : 12 items
# test/0011868/ : 12 items
# test/0011869/ : 32 items
# test/0011870/ : 24 items
# test/0011871/ : 16 items
# test/0011872/ : 8 items
# test/0011873/ : 40 items
# test/0011874/ : 36 items
# test/0011875/ : 20 items
# test/0011876/ : 40 items
# test/0011877/ : 12 items
# test/0011878/ : 4 items
# test/0011879/ : 16 items
# test/0011880/ : 36 items
# test/0011881/ : 16 items
# test/0011882/ : 20 items
# test/0011883/ : 16 items
# test/0011884/ : 4 items
# test/0011885/ : 8 items
# test/0011886/ : 4 items
# test/0011887/ : 8 items
# test/0011888/ : 32 items
# test/0011889/ : 32 items
# test/0011890/ : 4 items
# test/0011891/ : 12 items
# test/0011892/ : 20 items
# test/0011893/ : 4 items
# test/0011894/ : 4 items
# test/0011895/ : 8 items
# test/0011896/ : 28 items
# test/0011897/ : 8 items
# test/0011898/ : 8 items
# test/0011899/ : 20 items
# test/0011900/ : 8 items
# test/0011901/ : 8 items
# test/0011902/ : 44 items
# test/0011903/ : 56 items
# test/0011904/ : 4 items
# test/0011905/ : 8 items
# test/0011906/ : 16 items
# test/0011907/ : 4 items
# test/0011908/ : 8 items
# test/0011909/ : 8 items
# test/0011910/ : 4 items
# test/0011911/ : 88 items
# test/0011912/ : 28 items
# test/0011913/ : 16 items
# test/0011914/ : 8 items
# test/0011915/ : 20 items
# test/0011916/ : 40 items
# test/0011917/ : 20 items
# test/0011918/ : 40 items
# test/0011919/ : 24 items
# test/0011920/ : 4 items
# test/0011921/ : 4 items
# test/0011922/ : 12 items
# test/0011923/ : 8 items
# test/0011924/ : 16 items
# test/0011925/ : 12 items
# test/0011926/ : 16 items
# test/0011927/ : 64 items
# test/0011928/ : 4 items
# test/0011929/ : 36 items
# test/0011930/ : 32 items
# test/0011931/ : 24 items
# test/0011932/ : 8 items
# test/0011933/ : 20 items
# test/0011934/ : 16 items
# test/0011935/ : 12 items
# test/0011936/ : 8 items
# test/0011937/ : 24 items
# test/0011938/ : 8 items
# test/0011939/ : 28 items
# test/0011940/ : 20 items
# test/0011941/ : 20 items
# test/0011942/ : 52 items
# test/0011943/ : 12 items
# test/0011944/ : 16 items
# test/0011945/ : 8 items
# test/0011946/ : 32 items
# test/0011947/ : 4 items
# test/0011948/ : 44 items
# test/0011949/ : 8 items
# test/0011950/ : 4 items
# test/0011951/ : 4 items
# test/0011952/ : 4 items
# test/0011953/ : 8 items
# test/0011954/ : 24 items
# test/0011955/ : 24 items
# test/0011956/ : 16 items
# test/0011957/ : 40 items
# test/0011958/ : 12 items
# test/0011959/ : 12 items
# test/0011960/ : 20 items
# test/0011961/ : 24 items
# test/0011962/ : 4 items
# test/0011963/ : 36 items
# test/0011964/ : 36 items
# test/0011965/ : 20 items
# test/0011966/ : 4 items
# test/0011967/ : 4 items
# test/0011968/ : 28 items
# test/0011969/ : 16 items
# test/0011970/ : 32 items
# test/0011971/ : 16 items
# test/0011972/ : 4 items
# test/0011973/ : 20 items
# test/0011974/ : 4 items
# test/0011975/ : 24 items
# test/0011976/ : 8 items
# test/0011977/ : 36 items
# test/0011978/ : 8 items
# test/0011979/ : 4 items
# test/0011980/ : 8 items
# test/0011981/ : 28 items
# test/0011982/ : 8 items
# test/0011983/ : 12 items
# test/0011984/ : 12 items
# test/0011985/ : 36 items
# test/0011986/ : 8 items
# test/0011987/ : 4 items
# test/0011988/ : 24 items
# test/0011989/ : 12 items
# test/0011990/ : 20 items
# test/0011991/ : 12 items
# test/0011992/ : 4 items
# test/0011993/ : 8 items
# test/0011994/ : 12 items
# test/0011995/ : 4 items
# test/0011996/ : 4 items
# test/0011997/ : 20 items
# test/0011998/ : 40 items
# test/0011999/ : 28 items
# test/0012000/ : 16 items
# test/0012001/ : 8 items
# test/0012002/ : 16 items
# test/0012003/ : 28 items
# train/airport/ : 5736 items
# train/airport_hangar/ : 19888 items
# train/airport_terminal/ : 18328 items
# train/amusement_park/ : 23552 items
# train/aquaculture/ : 6576 items
# train/archaeological_site/ : 10688 items
# train/barn/ : 24956 items
# train/border_checkpoint/ : 6024 items
# train/burial_site/ : 16884 items
# train/car_dealership/ : 20872 items
# train/construction_site/ : 13304 items
# train/crop_field/ : 99352 items
# train/dam/ : 17372 items
# train/debris_or_rubble/ : 8392 items
# train/educational_institution/ : 48828 items
# train/electric_substation/ : 22504 items
# train/factory_or_powerplant/ : 14652 items
# train/fire_station/ : 21324 items
# train/flooded_road/ : 8292 items
# train/fountain/ : 23056 items
# train/gas_station/ : 22520 items
# train/golf_course/ : 15520 items
# train/ground_transportation_station/ : 43876 items
# train/helipad/ : 17480 items
# train/hospital/ : 21464 items
# train/impoverished_settlement/ : 5464 items
# train/interchange/ : 15252 items
# train/lake_or_pond/ : 3572 items
# train/lighthouse/ : 15072 items
# train/military_facility/ : 51072 items
# train/multi-unit_residential/ : 31012 items
# train/nuclear_powerplant/ : 892 items
# train/office_building/ : 23428 items
# train/oil_or_gas_facility/ : 18092 items
# train/park/ : 20016 items
# train/parking_lot_or_garage/ : 53816 items
# train/place_of_worship/ : 77140 items
# train/police_station/ : 21172 items
# train/port/ : 7496 items
# train/prison/ : 17708 items
# train/race_track/ : 22228 items
# train/railway_bridge/ : 19000 items
# train/recreational_facility/ : 115532 items
# train/road_bridge/ : 21264 items
# train/runway/ : 9896 items
# train/shipyard/ : 2728 items
# train/shopping_mall/ : 23572 items
# train/single-unit_residential/ : 42788 items
# train/smokestack/ : 20308 items
# train/solar_farm/ : 20636 items
# train/space_facility/ : 856 items
# train/stadium/ : 23652 items
# train/storage_tank/ : 21996 items
# train/surface_mine/ : 20524 items
# train/swimming_pool/ : 33664 items
# train/toll_booth/ : 21588 items
# train/tower/ : 29724 items
# train/tunnel_opening/ : 25320 items
# train/waste_disposal/ : 17204 items
# train/water_treatment_facility/ : 22068 items
# train/wind_farm/ : 20624 items
# train/zoo/ : 6472 items
# val/airport/ : 902 items
# val/airport_hangar/ : 2812 items
# val/airport_terminal/ : 2388 items
# val/amusement_park/ : 3308 items
# val/aquaculture/ : 972 items
# val/archaeological_site/ : 1488 items
# val/barn/ : 3360 items
# val/border_checkpoint/ : 988 items
# val/burial_site/ : 2504 items
# val/car_dealership/ : 3124 items
# val/construction_site/ : 2008 items
# val/crop_field/ : 14428 items
# val/dam/ : 2412 items
# val/debris_or_rubble/ : 1340 items
# val/educational_institution/ : 6672 items
# val/electric_substation/ : 3440 items
# val/factory_or_powerplant/ : 2188 items
# val/fire_station/ : 2944 items
# val/flooded_road/ : 1304 items
# val/fountain/ : 3408 items
# val/gas_station/ : 3148 items
# val/golf_course/ : 2268 items
# val/ground_transportation_station/ : 6140 items
# val/helipad/ : 2880 items
# val/hospital/ : 3112 items
# val/impoverished_settlement/ : 772 items
# val/interchange/ : 2280 items
# val/lake_or_pond/ : 420 items
# val/lighthouse/ : 1996 items
# val/military_facility/ : 7844 items
# val/multi-unit_residential/ : 4728 items
# val/nuclear_powerplant/ : 128 items
# val/office_building/ : 3276 items
# val/oil_or_gas_facility/ : 2568 items
# val/park/ : 2892 items
# val/parking_lot_or_garage/ : 7800 items
# val/place_of_worship/ : 11652 items
# val/police_station/ : 3080 items
# val/port/ : 1064 items
# val/prison/ : 2548 items
# val/race_track/ : 3380 items
# val/railway_bridge/ : 2808 items
# val/recreational_facility/ : 16924 items
# val/road_bridge/ : 3216 items
# val/runway/ : 1496 items
# val/shipyard/ : 304 items
# val/shopping_mall/ : 3604 items
# val/single-unit_residential/ : 6756 items
# val/smokestack/ : 2644 items
# val/solar_farm/ : 2528 items
# val/space_facility/ : 176 items
# val/stadium/ : 3460 items
# val/storage_tank/ : 3356 items
# val/surface_mine/ : 2984 items
# val/swimming_pool/ : 5148 items
# val/toll_booth/ : 3324 items
# val/tower/ : 4224 items
# val/tunnel_opening/ : 3760 items
# val/waste_disposal/ : 2464 items
# val/water_treatment_facility/ : 2984 items
# val/wind_farm/ : 3060 items
# val/zoo/ : 976 items

# %% [markdown]
# Dowload the training and validation to local machine. Only download folders of classes we need.

# %%
# we need to build a list of the folder paths we want.
target_paths = []
for category in target_classes:
    target_paths.append(f"train/{category}/")
    target_paths.append(f"val/{category}/")
print(target_paths)

def matches_target_paths(file_path, target_folders):
    return any(file_path.startswith(folder) for folder in target_folders)

# we can query this function like so
positive_example = 'train/wind_farm/'
negative_example = 'val/tower/'

print(f"Positive: {matches_target_paths(positive_example, target_paths)}")
print(f"Negative: {matches_target_paths(negative_example, target_paths)}")
# Out:
# ['train/electric_substation/', 'val/electric_substation/', 'train/factory_or_powerplant/', 'val/factory_or_powerplant/', 'train/gas_station/', 'val/gas_station/', 'train/nuclear_powerplant/', 'val/nuclear_powerplant/', 'train/oil_or_gas_facility/', 'val/oil_or_gas_facility/', 'train/solar_farm/', 'val/solar_farm/', 'train/space_facility/', 'val/space_facility/', 'train/waste_disposal/', 'val/waste_disposal/', 'train/water_treatment_facility/', 'val/water_treatment_facility/', 'train/wind_farm/', 'val/wind_farm/']
# Positive: True
# Negative: False

# %% [markdown]
# Each example has 4 files: the multispectral rgb jpeg and associated json as well as the regular rgb and associated json. We will start with one version and compare with the other if time allows. For now, let's look at the difference.

# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import os

def load_img(path):

    # parse the paths from the input path
    img_path = f"{path}.jpg"
    json_path = f"{path}.json"

    # load the image and metadata
    img_local = os.path.basename(img_path)
    json_local = os.path.basename(json_path)

    s3.download_file(bucket_name, prefix + img_path, img_local)
    s3.download_file(bucket_name, prefix + json_path, json_local)

    img = Image.open(img_local).convert("RGB")
    with open(json_local, 'r') as f:
        metadata = json.load(f)

    # each image has bounding boxes to indicate class instances
    draw = ImageDraw.Draw(img)
    ids = []

    for box in metadata.get("bounding_boxes", []):

        # get the label for this id
        try:
            ids.append(box["category"])
        except ValueError:
            ids.append("unkown")

        # draw the box within the image
        x_min, y_min, width, height = box["box"]
        draw.rectangle([x_min, y_min, x_min + width, y_min + height], outline="red", width=2)

    return img, ids

# load both spectral versions and their annotations
img_rgb, ids_rgb = load_img("train/electric_substation/electric_substation_0/electric_substation_0_0_rgb")
img_msrgb, ids_msrgb = load_img("train/electric_substation/electric_substation_0/electric_substation_0_0_msrgb")

# plot them side by side
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(img_rgb)
axes[0].set_title(f"RGB Image\nLabel: {ids_rgb[0]}")
axes[0].axis('off')
axes[1].imshow(img_msrgb)
axes[1].set_title(f"MSRGB Image\nLabel: {ids_msrgb[0]}")
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Notice how the bounding box in the multispectral image is thicker. This is because the "width" attribute is pixel-dependent, and the msrgb images are scaled down to maintain picture integrity at a lower resolution.

# %%
# compare the image sizes
print("RGB size:", img_rgb.size)
print("MSRGB size:", img_msrgb.size)
# Out:
# RGB size: (942, 640)
# MSRGB size: (236, 161)

# %% [markdown]
# We will train on msrg images to start because they have a lower computational overhead.
#
# One more thing to note before we are ready for download: The images come with bounding boxes indicating where the class instance is in the picture. Because this specificity is available to us, we intend to use it. Since, however, it might be interesting to compare if some models work better with more context, we will look into both.

# %%
def load_and_crop(path):

    # parse the paths from the input path
    img_path = f"{path}.jpg"
    json_path = f"{path}.json"

    # load the image and metadata
    img_local = os.path.basename(img_path)
    json_local = os.path.basename(json_path)

    s3.download_file(bucket_name, prefix + img_path, img_local)
    s3.download_file(bucket_name, prefix + json_path, json_local)

    img = Image.open(img_local).convert("RGB")
    with open(json_local, 'r') as f:
        metadata = json.load(f)

    crops = []
    labels = []

    for i, box in enumerate(metadata.get("bounding_boxes", [])):
        label = box["category"]
        x_min, y_min, width, height = box['box']
        cropped = img.crop((x_min, y_min, x_min + width, y_min + height))
        crops.append(cropped)
        labels.append(label)

    return crops, labels


# load both spectral versions and their annotations
boxed_img, boxed_id = load_img("train/electric_substation/electric_substation_0/electric_substation_0_0_msrgb")
cropped_img, cropped_id = load_and_crop("train/electric_substation/electric_substation_0/electric_substation_0_0_msrgb")

# plot them side by side
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(boxed_img)
axes[0].set_title(f"Uncropped Image\nLabel: {boxed_id[0]}")
axes[0].axis('off')
axes[1].imshow(cropped_img[0])
axes[1].set_title(f"Cropped Image\nLabel: {cropped_id[0]}")
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The tensorflow architectural pipeline requires square images. Instead of cropping the exact bounding box, we will crop the tightest fitting square around the bounding box.

# %%
def load_img_square(path):

    # parse the paths from the input path
    img_path = f"{path}.jpg"
    json_path = f"{path}.json"

    # load the image and metadata
    img_local = os.path.basename(img_path)
    json_local = os.path.basename(json_path)

    s3.download_file(bucket_name, prefix + img_path, img_local)
    s3.download_file(bucket_name, prefix + json_path, json_local)

    img = Image.open(img_local).convert("RGB")
    with open(json_local, 'r') as f:
        metadata = json.load(f)

    # each image has bounding boxes to indicate class instances
    draw = ImageDraw.Draw(img)
    ids = []

    for box in metadata.get("bounding_boxes", []):

        # get the label for this id
        try:
            ids.append(box["category"])
        except ValueError:
            ids.append("unkown")

        # draw the box, squared at its center
        x_min, y_min, width, height = box["box"]
        max_dim = max(width, height)
        x_min = x_min + (width - max_dim) // 2
        y_min = y_min + (height - max_dim) // 2
        width, height = max_dim, max_dim

        draw.rectangle([x_min, y_min, x_min + width, y_min + height], outline="red", width=2)

    return img, ids

# load both spectral versions and their annotations
img_rgb, ids_rgb = load_img("train/electric_substation/electric_substation_0/electric_substation_0_0_msrgb")
img_msrgb, ids_msrgb = load_img_square("train/electric_substation/electric_substation_0/electric_substation_0_0_msrgb")

# plot them side by side
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(img_rgb)
axes[0].set_title(f"Provided Box\nLabel: {ids_rgb[0]}")
axes[0].axis('off')
axes[1].imshow(img_msrgb)
axes[1].set_title(f"Squared Box\nLabel: {ids_msrgb[0]}")
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Pillow's behavior if you try to extend the square beyond the dimensions of the image is to truncate the crop at the edges of the image -- so those images wouldn't come out square. When we feed to tensorflow, it defaults transforms images to be in a square via aspect ratio distortion. We'll keep track of how many examples this occurs for, but it shouldn't be a problem overall.

# %%
def crop_and_download(file_stem, missing_files, missing_count, verbose=True):

    # parse the paths from the input path
    img_path = f"{file_stem}.jpg"
    json_path = f"{file_stem}.json"

    # load the image and metadata
    img_local = Path('fmow_msrgb_dataset/images') / Path(img_path)
    json_local = Path('fmow_msrgb_dataset/metadata') / Path(json_path)

    # download the images to their respective directories
    img_local.parent.mkdir(parents=True, exist_ok=True)
    json_local.parent.mkdir(parents=True, exist_ok=True)
    s3.download_file(bucket_name, prefix + img_path, str(img_local))
    s3.download_file(bucket_name, prefix + json_path, str(json_local))

    # we need to download and open the image before we can crop
    img = Image.open(img_local).convert("RGB")
    with open(json_local, 'r') as f:
        metadata = json.load(f)

    # each image has bounding boxes to indicate class instances
    multiple_bounding_boxes = []

    for i, box in enumerate(metadata.get("bounding_boxes", [])):

        # keep track of multiple bounding boxes
        if i >= 1:
              multiple_bounding_boxes.append(image_local)
              img_path = f"{file_stem}_{i}.jpg"
              img_local = Path('fmow_msrgb_dataset/images') / Path(img_path)

        # pull box information
        x_min, y_min, width, height = box['box']

        # resize to be squared at box center
        x_min, y_min, width, height = box["box"]
        max_dim = max(width, height)
        x_min = x_min + (width - max_dim) // 2
        y_min = y_min + (height - max_dim) // 2
        width, height = max_dim, max_dim

        # crop the image overwrite the uncropped jpg
        cropped = img.crop((x_min, y_min, x_min + width, y_min + height))
        cropped.save(img_local, format="JPEG")

    return missing_files, missing_count, multiple_bounding_boxes

# %% [markdown]
# ##Download the Data

# %%
from pathlib import Path
import os
import json

def download_fmow(manifest, cropped=True):

    manifest_set = set(manifest)
    missing_files = []
    missing_count = 0

    for file_path in manifest:

        # check if this is in a folder that we want
        if matches_target_paths(file_path, target_paths) and file_path.endswith('_msrgb.jpg'):
            
            file_stem = file_path.removesuffix('.jpg')

            if cropped:
                # this will download both files to folder structure
                missing_files, missing_count, multiple_bounding_boxes = \
                crop_and_download(file_stem, missing_files, missing_count)
            else:
                # download the image file
                local_path = Path('fmow_msrgb_dataset/images') / Path(file_path)
                local_path.parent.mkdir(parents=True, exist_ok=True)
                s3.download_file(bucket_name, prefix + file_path, str(local_path))

            # download the associated metadata file
            meta_path = file_stem + '.json'
            if meta_path in manifest_set:
                local_path = Path('fmow_msrgb_dataset/metadata') / Path(meta_path)
                local_path.parent.mkdir(parents=True, exist_ok=True)
                s3.download_file(bucket_name, prefix + meta_path, str(local_path))
            else:
                # keep track of missing files, but continue data download
                missing_count += 1
                missing_files.append(meta_path)
    
    return missing_files, missing_count, multiple_bounding_boxes

# %%
missing_files, missing_count, multiple_bounding_boxes = download_fmow(manifest, cropped=False)

# %% [markdown]
# Use this if you want just the raw images instead.

# %%
# Deprecated code to download

manifest_set = set(manifest)
for file_path in manifest:

    # check if this is a file we want
    if matches_target_paths(file_path, target_paths):

        # separate the images from the metadata
        if file_path.endswith('_msrgb.jpg'):

            # download the file to correct folder
            local_path = Path('fmow_msrgb_dataset/images') / Path(file_path)
            local_path.parent.mkdir(parents=True, exist_ok=True)
            s3.download_file(bucket_name, prefix + file_path, str(local_path))

        if file_path.endswith('_msrgb.json'):
            local_path = Path('fmow_msrgb_dataset/metadata')/ Path(file_path)
            local_path.parent.mkdir(parents=True, exist_ok=True)
            s3.download_file(bucket_name, prefix + file_path, str(local_path))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-5316bd85636d> in <cell line: 0>()
#      17             local_path = Path('fmow_msrgb_dataset/images') / Path(file_path)
#      18             local_path.parent.mkdir(parents=True, exist_ok=True)
# ---> 19             s3.download_file(bucket_name, prefix + file_path, str(local_path))
#      20
#      21         if file_path.endswith('_msrgb.json'):
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     121                 if hook:
#     122                     hook()
# --> 123                 return func(*args, **kwargs)
#     124
#     125         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     221     """
#     222     with S3Transfer(self, Config) as transfer:
# --> 223         return transfer.download_file(
#     224             bucket=Bucket,
#     225             key=Key,
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     404         )
#     405         try:
# --> 406             future.result()
#     407         # This is for backwards compatibility where when retries are
#     408         # exceeded we need to throw the same error from boto3 instead of
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/futures.py in result(self)
#     112         except KeyboardInterrupt as e:
#     113             self.cancel()
# --> 114             raise e
#     115
#     116     def cancel(self):
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/futures.py in result(self)
#     109             # however if a KeyboardInterrupt is raised we want want to exit
#     110             # out of this and propagate the exception.
# --> 111             return self._coordinator.result()
#     112         except KeyboardInterrupt as e:
#     113             self.cancel()
#
# /usr/local/lib/python3.11/dist-packages/s3transfer/futures.py in result(self)
#     265         # possible value integer value, which is on the scale of billions of
#     266         # years...
# --> 267         self._done_event.wait(MAXINT)
#     268
#     269         # Once done waiting, raise an exception if present or return the
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     627             signaled = self._flag
#     628             if not signaled:
# --> 629                 signaled = self._cond.wait(timeout)
#     630             return signaled
#     631
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     325         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#     329             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #Filter and Dowload the Test Data
#
# The training and validation data have a nice folder structure to make download easy. Unfortunately, the test data does not come with categories attached, but 'groundtruth.tar.bz2' in the manifest contains a mapping file, 'test_gt_mapping.json', which we will use to merge the proper metadata files with the test images and organize them into folders matching the train and val sets.

# %%
# we need to build a list of the folder paths we want.
target_paths = []
for category in target_classes:
    target_paths.append(f"test_gt/{category}/")
print(target_paths)

def matches_target_paths(file_path, target_folders):
    return any(file_path.startswith(folder) for folder in target_folders)

# we can query this function like so
positive_example = 'test_gt/wind_farm/wind_farm_0/wind_farm_0_0_msrgb.json'
negative_example = 'test_gt/tower/tower_0/tower_0_0_msrgb.json'

print(f"Positive: {matches_target_paths(positive_example, target_paths)}")
print(f"Negative: {matches_target_paths(negative_example, target_paths)}")
# Out:
# ['test_gt/electric_substation/', 'test_gt/factory_or_powerplant/', 'test_gt/gas_station/', 'test_gt/nuclear_powerplant/', 'test_gt/oil_or_gas_facility/', 'test_gt/solar_farm/', 'test_gt/space_facility/', 'test_gt/waste_disposal/', 'test_gt/water_treatment_facility/', 'test_gt/wind_farm/']
# Positive: True
# Negative: False

# %%
import tarfile

# let's download groundtruth.tar.bz2 to map test images to their categories
groundtruth_key = prefix + 'groundtruth.tar.bz2'
local_groundtruth = 'groundtruth.tar.bz2'
s3.download_file(bucket_name, groundtruth_key, local_groundtruth)
print(f"Downloaded {local_groundtruth} to current directory.")

# extract groundtruth files into 'groundtruth/' folder
with tarfile.open('groundtruth.tar.bz2', 'r:bz2') as tar:
    target_files = 0
    for member in tar:
        # this mapping file will be the last file you need
        if member.name == 'test_gt_mapping.json':
            tar.extract(member, path='groundtruth')
            print(f"Found {target_files} target files and one mapping file. Stopping early.")
            break

        # extract the only test files that also pertain to target class
        if matches_target_paths(member.name, target_paths):
            tar.extract(member, path='groundtruth')
            target_files += 1
# Out:
# Downloaded groundtruth.tar.bz2 to current directory.
# Found 13450 target files and one mapping file. Stopping early.

# %% [markdown]
# Now we have the full jsons for the test files and the mapping file, which contains has many dicts like this:
#
# {"input": "test_gt/oil_or_gas_facility/oil_or_gas_facility_68", "output": "test/0000045", "box_mapping": [{"input": 71492, "output": 57, "label": "oil_or_gas_facility"}]}
#
# We need to restore the modified test code to the actual labels.

# %%
with open('groundtruth/test_gt_mapping.json', 'r') as f:
    mapping_entries = json.load(f)

for entry in mapping_entries[:5]:
    print(f"input: {entry['input']}")
    print(f"output: {entry['output']}")
    print(f"box_mappings: {entry['box_mapping']}")
    print()
# Out:
# input: test_gt/storage_tank/storage_tank_168
# output: test/0000002
# box_mappings: [{'input': 111185, 'output': 1, 'label': 'storage_tank'}]
#
# input: test_gt/surface_mine/surface_mine_255
# output: test/0000022
# box_mappings: [{'input': 108593, 'output': 25, 'label': 'surface_mine'}]
#
# input: test_gt/helipad/helipad_120
# output: test/0000014
# box_mappings: [{'input': 92203, 'output': 16, 'label': 'helipad'}]
#
# input: test_gt/barn/barn_239
# output: test/0000016
# box_mappings: [{'input': 99002, 'output': 19, 'label': 'barn'}]
#
# input: test_gt/crop_field/crop_field_431
# output: test/0000017
# box_mappings: [{'input': 60211, 'output': 20, 'label': 'crop_field'}]
